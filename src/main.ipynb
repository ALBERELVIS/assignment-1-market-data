# %% [markdown]
# <a href="https://colab.research.google.com/github/ALBERELVIS/assignment-1-market-data/blob/main/src/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# Assignment 1 – Market Data Toolkit
# Author: Dr. Albert Martin
# ==========================================

# This its a simply check of the system and python version

import sys

print("Python version:", sys.version)
print("Let's Get ready to ruuummmbleee") # Nice reference eh?
# Out:
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Let's Get ready to ruuummmbleee

# %% [markdown]
# #Extractor Module (Data Downloader)

# %%
####### Extractor Module (Data Downloader) #######

#Primero instalamos los paquetes
# !pip install yfinance pandas numpy

#And we import the libaries
import yfinance, pandas, numpy
print("All libraries are correctly installed and ready to use.")
# Out:
# ...
# All libraries are correctly installed and ready to use.
